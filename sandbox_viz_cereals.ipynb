# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
cereal_df = pd.read_csv("cereal.csv")

# %%
cereal_df
# Out:
#                          name mfr type  calories  protein  fat  sodium  fiber  \
# 0                   100% Bran   N    C        70        4    1     130   10.0
# 1           100% Natural Bran   Q    C       120        3    5      15    2.0
# 2                    All-Bran   K    C        70        4    1     260    9.0
# 3   All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
# 4              Almond Delight   R    C       110        2    2     200    1.0
# ..                        ...  ..  ...       ...      ...  ...     ...    ...
# 72                    Triples   G    C       110        2    1     250    0.0
# 73                       Trix   G    C       110        1    1     140    0.0
# 74                 Wheat Chex   R    C       100        3    1     230    3.0
# 75                   Wheaties   G    C       100        3    1     200    3.0
# 76        Wheaties Honey Gold   G    C       110        2    1     200    1.0
#
# ...

# %%
cereal_df["fiber"].hist(bins=14)
plt.show()

# %%
# Needed something categorical, used the 'mfr' column (Manufacturer) and got calories per mfr.
man_cereal_df = cereal_df.groupby("mfr")["calories"].mean()
print(man_cereal_df)
# Out:
# mfr
# A    100.000000
# G    111.363636
# K    108.695652
# N     86.666667
# P    108.888889
# Q     95.000000
# R    115.000000
# Name: calories, dtype: float64

# %%
# can use kind="line" if using time data
man_cereal_df.plot(kind="bar", rot=0)
plt.title("Avg. Calories per Manufacturer")
plt.xlabel("Manufacturer")
plt.ylabel("Calories")
plt.show()

# %%
# scatter
cereal_df.plot(x="sugars", y="fat", kind="scatter")
plt.show()

# %%
avocados = pd.read_csv("avocado.csv")

# %%
avocados.head()
# Out:
#    Unnamed: 0        Date  AveragePrice  Total Volume     4046       4225  \
# 0           0  2015-12-27          1.33      64236.62  1036.74   54454.85
# 1           1  2015-12-20          1.35      54876.98   674.28   44638.81
# 2           2  2015-12-13          0.93     118220.22   794.70  109149.67
# 3           3  2015-12-06          1.08      78992.15  1132.00   71976.41
# 4           4  2015-11-29          1.28      51039.60   941.48   43838.39
#
#      4770  Total Bags  Small Bags  Large Bags  XLarge Bags          type  \
# 0   48.16     8696.87     8603.62       93.25          0.0  conventional
# 1   58.33     9505.56     9408.07       97.49          0.0  conventional
# 2  130.50     8145.35     8042.21      103.14          0.0  conventional
# 3   72.58     5811.16     5677.40      133.76          0.0  conventional
# 4   75.78     6183.95     5986.26      197.69          0.0  conventional
#
#    year  region
# 0  2015  Albany
# 1  2015  Albany
# 2  2015  Albany
# ...

# %%
pd.unique(avocados["type"])
# Out:
# array(['conventional', 'organic'], dtype=object)

# %%
pd.unique(avocados["region"])
# Out:
# array(['Albany', 'Atlanta', 'BaltimoreWashington', 'Boise', 'Boston',
#        'BuffaloRochester', 'California', 'Charlotte', 'Chicago',
#        'CincinnatiDayton', 'Columbus', 'DallasFtWorth', 'Denver',
#        'Detroit', 'GrandRapids', 'GreatLakes', 'HarrisburgScranton',
#        'HartfordSpringfield', 'Houston', 'Indianapolis', 'Jacksonville',
#        'LasVegas', 'LosAngeles', 'Louisville', 'MiamiFtLauderdale',
#        'Midsouth', 'Nashville', 'NewOrleansMobile', 'NewYork',
#        'Northeast', 'NorthernNewEngland', 'Orlando', 'Philadelphia',
#        'PhoenixTucson', 'Pittsburgh', 'Plains', 'Portland',
#        'RaleighGreensboro', 'RichmondNorfolk', 'Roanoke', 'Sacramento',
#        'SanDiego', 'SanFrancisco', 'Seattle', 'SouthCarolina',
#        'SouthCentral', 'Southeast', 'Spokane', 'StLouis', 'Syracuse',
#        'Tampa', 'TotalUS', 'West', 'WestTexNewMexico'], dtype=object)

# %%
# I can calculate the totals in each column, I don't need figures telling me.
avocados.drop(avocados[avocados.region == "TotalUS"].index, inplace=True)

# %%
pd.unique(avocados["region"])
# Out:
# array(['Albany', 'Atlanta', 'BaltimoreWashington', 'Boise', 'Boston',
#        'BuffaloRochester', 'California', 'Charlotte', 'Chicago',
#        'CincinnatiDayton', 'Columbus', 'DallasFtWorth', 'Denver',
#        'Detroit', 'GrandRapids', 'GreatLakes', 'HarrisburgScranton',
#        'HartfordSpringfield', 'Houston', 'Indianapolis', 'Jacksonville',
#        'LasVegas', 'LosAngeles', 'Louisville', 'MiamiFtLauderdale',
#        'Midsouth', 'Nashville', 'NewOrleansMobile', 'NewYork',
#        'Northeast', 'NorthernNewEngland', 'Orlando', 'Philadelphia',
#        'PhoenixTucson', 'Pittsburgh', 'Plains', 'Portland',
#        'RaleighGreensboro', 'RichmondNorfolk', 'Roanoke', 'Sacramento',
#        'SanDiego', 'SanFrancisco', 'Seattle', 'SouthCarolina',
#        'SouthCentral', 'Southeast', 'Spokane', 'StLouis', 'Syracuse',
#        'Tampa', 'West', 'WestTexNewMexico'], dtype=object)

# %%
mean_av_region_total = avocados.groupby("region")["Total Bags"].mean()

# %%
plt.figure(figsize=(18,6))
mean_av_region_total.plot(kind="bar")
plt.show()

# %%
av_sold_by_date_total = avocados.groupby("Date")["Total Bags"].sum()
av_sold_by_date_small = avocados.groupby("Date")["Small Bags"].sum()
av_sold_by_date_large = avocados.groupby("Date")["Large Bags"].sum()
av_sold_by_date_xlarge = avocados.groupby("Date")["XLarge Bags"].sum()

# %%
#no 'type' as 'plot' defaults to line type.
# comparing all types of bag sales over time.
plt.figure(figsize=(19,8))
av_sold_by_date_small.plot()
av_sold_by_date_large.plot()
av_sold_by_date_xlarge.plot()
plt.legend()
plt.title("Avocado Bag Size Sales Over Time")
plt.xlabel("Date")
plt.ylabel("Bags Sold (1,000's)")
plt.grid()
plt.show()

# %%
avo_conv = avocados[avocados["type"] == "conventional"]
avo_org = avocados[avocados["type"] == 'organic']

# %%
avo_conv_mean = avo_conv["AveragePrice"].mean()

# %%
avo_org_mean = avo_org["AveragePrice"].mean()

# %%
avocados["AveragePrice"]["type"].mean()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-136-50baaac3a998> in <module>
# ----> 1 avocados["AveragePrice"]["type"].mean()
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\series.py in __getitem__(self, key)
#    1066         key = com.apply_if_callable(key, self)
#    1067         try:
# -> 1068             result = self.index.get_value(self, key)
#    1069
#    1070             if not is_scalar(result):
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_value(self, series, key)
#    4728         k = self._convert_scalar_indexer(k, kind="getitem")
#    4729         try:
# -> 4730             return self._engine.get_value(s, k, tz=getattr(series.dtype, "tz", None))
#    4731         except KeyError as e1:
#    4732             if len(self) > 0 and (self.holds_integer() or self.is_boolean()):
#
# ...

# %%
plt.hist(avo_conv_mean)
plt.hist(avo_org_mean)
plt.legend()
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
# remember avocados[avocados["type"] == 'conventional'] returns a dataframe. then we add on averageprice for that column.
avocados[avocados["type"] == 'conventional']["AveragePrice"].hist(bins=20)
avocados[avocados["type"] == 'organic']["AveragePrice"].hist(bins=20)
plt.legend(["Conventional","Organic"])
plt.show()
